# %% [markdown]
# <a href="https://colab.research.google.com/github/TirthhShethh/Home-Price-prediction/blob/main/Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Loadind Data**

# %%
data = pd.read_csv('home_dataset.csv')
print(data)
# Out:
#     HouseSize  HousePrice
# 0         793     1300000
# 1        2477     3700000
# 2        1263     1480000
# 3        1291     2380000
# 4         603      955000
# 5        1655     2130000
# 6        1071     1300000
# 7        1877     2700000
# 8        1610     2650000
# 9        3058     2850000
# 10       1609     2250000
# 11       1630     2950000
# 12       1211     1900000
# 13       1219     1820000
# 14       1700     2100000
# 15       1629     2480000
# 16        740     1270000
# 17        740     1260000
# 18       1637     2520000
# 19       1637     3450000
# 20       1291     2430000
# 21       1211     2250000
# 22        400           1
# 23        800      925000
# 24        700      950000
# 25       1711     2630000
# 26        847      975000
# 27       1230     1570000
# 28       1291     2010000
# 29       2300     3630000
# 30        886     1120000
# 31       1700     2020000
# 32        389      695974
# 33        793     1330000
# 34        978     1460000
# 35        582      685000
# 36        793     1340000
# 37       1327     2440000
# 38        791      925000
# 39        793     1400000
# 40       1630     2980000
# 41        740     1200000
# 42       1244     1650000
# 43       1183     1880000
# 44       1327     2440000
# 45       1183     1880000
# 46       1643     2790000
# 47       2500     3470000
# 48       1085     1160000
# 49        740     1230000
# 50       1291     2180000
# 51       1291     2060000
# 52        740     1270000
# 53       1230     1660000
# 54       1219     1870000
# 55       1275     1800000
# 56        793     1330000
# 57       1259     1650000
# 58       1395     1950000

# %% [markdown]
# **Extracting features and target variables**

# %%
house_sizes = data["HouseSize"]
print(house_sizes)
# Out:
# 0      793
# 1     2477
# 2     1263
# 3     1291
# 4      603
# 5     1655
# 6     1071
# 7     1877
# 8     1610
# 9     3058
# 10    1609
# 11    1630
# 12    1211
# 13    1219
# 14    1700
# 15    1629
# 16     740
# 17     740
# 18    1637
# 19    1637
# 20    1291
# 21    1211
# 22     400
# 23     800
# 24     700
# 25    1711
# 26     847
# 27    1230
# 28    1291
# 29    2300
# 30     886
# 31    1700
# 32     389
# 33     793
# 34     978
# 35     582
# 36     793
# 37    1327
# 38     791
# 39     793
# 40    1630
# 41     740
# 42    1244
# 43    1183
# 44    1327
# 45    1183
# 46    1643
# 47    2500
# 48    1085
# 49     740
# 50    1291
# 51    1291
# 52     740
# 53    1230
# 54    1219
# 55    1275
# 56     793
# 57    1259
# 58    1395
# Name: HouseSize, dtype: int64

# %%
house_prices = data["HousePrice"]
print(house_prices)
# Out:
# 0     1300000
# 1     3700000
# 2     1480000
# 3     2380000
# 4      955000
# 5     2130000
# 6     1300000
# 7     2700000
# 8     2650000
# 9     2850000
# 10    2250000
# 11    2950000
# 12    1900000
# 13    1820000
# 14    2100000
# 15    2480000
# 16    1270000
# 17    1260000
# 18    2520000
# 19    3450000
# 20    2430000
# 21    2250000
# 22          1
# 23     925000
# 24     950000
# 25    2630000
# 26     975000
# 27    1570000
# 28    2010000
# 29    3630000
# 30    1120000
# 31    2020000
# 32     695974
# 33    1330000
# 34    1460000
# 35     685000
# 36    1340000
# 37    2440000
# 38     925000
# 39    1400000
# 40    2980000
# 41    1200000
# 42    1650000
# 43    1880000
# 44    2440000
# 45    1880000
# 46    2790000
# 47    3470000
# 48    1160000
# 49    1230000
# 50    2180000
# 51    2060000
# 52    1270000
# 53    1660000
# 54    1870000
# 55    1800000
# 56    1330000
# 57    1650000
# 58    1950000
# Name: HousePrice, dtype: int64

# %% [markdown]
# **Data Visualization**

# %%
plt.scatter(house_sizes, house_prices, marker = 'o', color = 'blue')
plt.title('House Prices vs. House Size')
plt.xlabel('House Size (sq.ft)')
plt.ylabel('House Price ($)')
plt.show()

# %% [markdown]
# **Train Test**

# %%
x_train, x_test, y_train, y_test = train_test_split(house_sizes, house_prices, test_size=0.2, random_state=42)
# 80% of the data will be used to train the algorithm in x_train and y_train.
# The other 20% will be used for testing the algorithm in x_test and y_test.

# %% [markdown]
# **Creating and Training the model**

# %%
# Reshape the data for NumPy
x_train = np.array(x_train).reshape(-1, 1)
x_test = np.array(x_test).reshape(-1, 1)

# Create and train the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Prediction**

# %%
predictions = model.predict(x_test)
plt.scatter(x_test, y_test, marker='o', color='blue', label='Actual Prices')
plt.plot(x_test, predictions, color='red', linewidth=2, label='Predicted Prices')
plt.title('Dumbo Property Price Prediction with Linear Regression')
plt.xlabel('House Size (sq.ft)')
plt.ylabel('House Price (millions $)')
plt.legend()
plt.show()
